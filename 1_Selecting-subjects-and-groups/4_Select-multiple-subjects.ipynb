# %% [markdown]
# # Select a list of subjects

# %%
import pandas as pd
import numpy as np
spreadsheet_file = 'example_data.xlsx'
df = pd.read_excel(spreadsheet_file)
df.head(3)
# Out:
#    ID  VIST_NUM  CLIN_STATUS FAMILY_GENE GENETIC_STATUS  AGE  SEX  COG_MEM  \
# 0  50         1          0.0          C9             C9   48    1      NaN
# 1  50         2          0.0          C9             C9   49    1      NaN
# 2  50         3          0.0          C9             C9   50    1      NaN
#
#    COG_ORI  COG_JUDG  COG_LANG  COG_VIS  COG_ATTN
# 0      NaN       NaN       NaN      NaN       NaN
# 1      NaN       NaN       NaN      NaN       NaN
# 2      NaN       NaN       NaN      NaN       NaN

# %% [markdown]
# Below is the list of subjects you want to keep

# %%
subjs_to_select = [50,64,125,282]

# %% [markdown]
# You can use the .isin pandas function to filter the original dataframe

# %%
new_df = df[df['ID'].isin(subjs_to_select)]
display(new_df)
# Out:
#     ID  VIST_NUM  CLIN_STATUS FAMILY_GENE GENETIC_STATUS  AGE  SEX  COG_MEM  \
# 0   50         1          0.0          C9             C9   48    1      NaN
# 1   50         2          0.0          C9             C9   49    1      NaN
# 2   50         3          0.0          C9             C9   50    1      NaN
# 3   50         4          0.0          C9             C9   51    1      NaN
# 4   64         1          0.5        NONE           NONE   81    2      0.0
# 5  125         1          1.0        NONE           NONE   54    2      0.0
# 6  282         1          0.0         GRN            GRN   34    1      NaN
# 7  282         2          0.0         GRN            GRN   35    1      NaN
# 8  282         3          0.0         GRN            GRN   36    1      NaN
# 9  282         4          0.0         GRN            GRN   37    1      NaN
#
#    COG_ORI  COG_JUDG  COG_LANG  COG_VIS  COG_ATTN
# 0      NaN       NaN       NaN      NaN       NaN
# ...

# %% [markdown]
# Then you just need to export the list
